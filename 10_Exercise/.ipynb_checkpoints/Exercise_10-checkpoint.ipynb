# %% [markdown]
# ## NOTEBOOK 10
#
# In this  notebook we are going to integrate the genetic algorithm of the previous lessonin order to integrate a way:
#
# - to perform a simulated annealing search of the best path
# - to use MPI library to perform more than one search of the best path in parallel

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### EXERCISE 10.1

# %% [markdown]
# In this first exercise we are going to solve the TSP with a **Simulated Annealing** (SA) algorithm. Now we no longer have a *population* of different individuals but a single solution candidate.
#
# The solution coded in the individual is randomly mutated using the mutation operators developed in the previous lesson and then this mutation is accepted or reject according to the simulated annealing criterium:
#
# - if the path of the new solution is shorter than the previous one the mutation is accepted
# - if instead the new path is longer, the solution is accepted with probability $e^{-(l_{new}-l_{old})/T}$, where T is the temperature of the system ($k_{B}=1$) that is chosen step by step in order to simulate its cooling.
#
#
# Now, as a first thing, we generate the two city configuration, on a circumference and inside a square.

# %%
circle=np.loadtxt("simulated_annealing/circle.dat")
square=np.loadtxt("simulated_annealing/square.dat")

xc=np.zeros(len(circle))
yc=np.zeros(len(circle))

xs=np.zeros(len(square))
ys=np.zeros(len(square))

for i in range(len(xc)):
    xc[i]=circle[i][0]
    yc[i]=circle[i][1]
    
for i in range(len(xs)):
    xs[i]=square[i][0]
    ys[i]=square[i][1]
    
    
##Plot

fig, (ax1,ax2)=plt.subplots(1,2,figsize=(13,6), dpi=80)

fig.suptitle("Cities generated for the TSP")

ax1.scatter(xc,yc)
ax1.set_title('Cities on a circle of $r=10$')
ax1.set(xlabel='x', ylabel='y')


ax2.scatter(xs,ys)
ax2.set_title('Cities in a square of $l=20$')
ax2.set(xlabel='x', ylabel='y')

plt.show()
plt.close()

# %% [markdown]
# Then we create an initial solution candidate and choose to iterate the mutation of the solution $n_{it}=10^{5}$ times.
#
# The initial temperature is chosen to be $T_{0}=50$ and the cooling proceeds gradually for the first $10^{3}$ steps until $T=1.0$, then it is set equal to $0.3$ and then, after other $10^{3}$ steps, equal to $0.001$; finally, after $10^{4}$ steps, set to $0.0001$
#
#
# We can show the length of the best path as a function of the iteration of our algorithm

# %%
data1=open("results/best_circle_annealing.dat",'r').read().split('\n')
data2=open("results/best_square_annealing.dat",'r').read().split('\n')


data1=[x.split(',') for x in data1]
data2=[x.split(',') for x in data2]

x1=[]
y1=[]
y2=[]

for i in range(len(data1)-1):
    x1.append(float(data1[i][0]))
    y1.append(float(data1[i][2]))
    y2.append(float(data2[i][2]))
    
fig, (ax1,ax2)=plt.subplots(1,2,figsize=(13,5), dpi=80)

fig.suptitle("Results for the TSP solved with a simulated annealing algorithm")

ax1.plot(x1,y1)
ax1.set_title('Path lenght per iteration on a circumference')
ax1.set(xlabel='Generation', ylabel='Tour lenght')
ax1.axhline(62,color="orange")
ax1.grid(True)


ax2.plot(x1,y2)
ax2.set_title('Path lenght per iterarion in a square')
ax2.set(xlabel='Generation', ylabel='Average lenght')
ax2.grid(True)

plt.show()
plt.close()

# %% [markdown]
# We can see that the circle case reaches the best possible path a lot before the $10^{5}$-th iteration, since it is the simpler case, but for the best path in the square case we need more steps.
#
# The best path found for each case is

# %%
ce_best_ind=np.loadtxt("results/ind_circle_annealing.dat")
ce_best_ind=[int(x) for x in ce_best_ind]

se_best_ind=np.loadtxt("results/ind_square_annealing.dat")
se_best_ind=[int(x) for x in se_best_ind]

xb=np.zeros(len(circle)+1)
yb=np.zeros(len(circle)+1)
xb2=np.zeros(len(square)+1)
yb2=np.zeros(len(square)+1)




for i in range(len(circle)):
    xb[i]=circle[ce_best_ind[i]][0]
    yb[i]=circle[ce_best_ind[i]][1]
    
for i in range(len(square)):
    xb2[i]=square[se_best_ind[i]][0]
    yb2[i]=square[se_best_ind[i]][1]
    
xb[len(circle)]=xb[0]
yb[len(circle)]=yb[0]

xb2[len(square)]=xb2[0]
yb2[len(square)]=yb2[0]

fig, (ax1,ax2)=plt.subplots(1,2,figsize=(13,5), dpi=80)

fig.suptitle("Best path found for the TSP solved with a simulated annealing algorithm")


ax1.plot(xb,yb, marker='o',linestyle='dashed')
ax1.set_title('Path on a circumference')
ax1.set(xlabel='x', ylabel='y')

ax2.plot(xb2,yb2, marker='o',linestyle='dashed')
ax2.set_title('Path in a square')
ax2.set(xlabel='x', ylabel='y')

plt.show()
plt.close()

# %% [markdown]
# These results are comparable with those obtained with the genetic algorithm in the previous lesson. The GA, due to the fact that every population contained $10^{3}$ individuals, needed fewer iterations ($\sim 500$), while here for a single individual we had to iterate $10^{5}$ times.
#
# |                                || Circumference | Square      |
# |--------------------------------||---------------|-------------|
# | **Genetic algorithm**          ||   62.4698     |  94.9176    |
# | **Simulated annealing**        ||   62.4698     |  94.9885    |

# %% [markdown]
# ### EXERCISE 10.2

# %% [markdown]
# In this exercise we will use the MPI library to perform different genetic algorithms in parallel in order to solve the TSP problem for $32$ cities inside a square.
#
# To take full advantage of the parallelization of the algorithm, we will introduce the concepts of *continents* and *migration*:
#
# - **continent** indicates every population that is initialized in parallel and has no contact with the others
# - **migration** is a mechanism to put in touch different continents: every $N_{migr}$ steps the best individual of each continents is transferred randomly to another one
#
# In order to exchange the best individuals between random continents we generated a vector containing a "tour", namely the different ranks from $0$ to MAX_RANK, and every time a migration was needed we randomly shuffled this vector. Then the migration was performed in a "ring-fashioned" way: every core sent its best individual to the next in the tour and received it from the previous one (with pbc).
#
# Here below are shown the results of a calculation with 4 continents,$n=2000$ steps and a migration every $100$ steps using the standard roulette wheel selection.

# %%
parallel0=open("results/parallel_roulette/best_square_0.dat",'r').read().split('\n')
parallel1=open("results/parallel_roulette/best_square_1.dat",'r').read().split('\n')
parallel2=open("results/parallel_roulette/best_square_2.dat",'r').read().split('\n')
parallel3=open("results/parallel_roulette/best_square_3.dat",'r').read().split('\n')

parallel0=[x.split(',') for x in parallel0]
parallel1=[x.split(',') for x in parallel1]
parallel2=[x.split(',') for x in parallel2]
parallel3=[x.split(',') for x in parallel3]

x=[]
y0=[]
y3=[]
y2=[]
y1=[]

for i in range(len(parallel1)-1):
    x.append(float(parallel0[i][0]))
    y0.append(float(parallel0[i][1]))
    y1.append(float(parallel1[i][1]))
    y2.append(float(parallel2[i][1]))
    y3.append(float(parallel3[i][1]))

plt.figure(figsize=(8,5))

plt.plot(x,y0,label="Core 0")
plt.plot(x,y1,label="Core 1")
plt.plot(x,y2,label="Core 2")
plt.plot(x,y3,label="Core 3")
plt.title("Best individual per generation on different cores")
plt.xlabel("Generation")
plt.ylabel("Tour lenght")

plt.legend()
plt.grid(True)
plt.show()
plt.close()

# %% [markdown]
# We can also look at the average of the best half per generation per core:

# %%
a_parallel0=open("results/parallel_roulette/average_square_0.dat",'r').read().split('\n')
a_parallel1=open("results/parallel_roulette/average_square_1.dat",'r').read().split('\n')
a_parallel2=open("results/parallel_roulette/average_square_2.dat",'r').read().split('\n')
a_parallel3=open("results/parallel_roulette/average_square_3.dat",'r').read().split('\n')

a_parallel0=[x.split(',') for x in a_parallel0]
a_parallel1=[x.split(',') for x in a_parallel1]
a_parallel2=[x.split(',') for x in a_parallel2]
a_parallel3=[x.split(',') for x in a_parallel3]

x=[]
y0=[]
y3=[]
y2=[]
y1=[]

for i in range(len(parallel1)-1):
    x.append(float(a_parallel0[i][0]))
    y0.append(float(a_parallel0[i][1]))
    y1.append(float(a_parallel1[i][1]))
    y2.append(float(a_parallel2[i][1]))
    y3.append(float(a_parallel3[i][1]))

plt.figure(figsize=(8,5))

plt.plot(x,y0,label="Core 0")
plt.plot(x,y1,label="Core 1")
plt.plot(x,y2,label="Core 2")
plt.plot(x,y3,label="Core 3")
plt.title("Average of the best half per generation on different cores")
plt.xlabel("Generation")
plt.ylabel("Tour lenght")

plt.legend()
plt.grid(True)
plt.show()
plt.close()

# %% [markdown]
# In the end, since we obtained the best results with elitism in the previous lesson, we can try to apply it also to the parallel version of the algorithm.
#
# Here we have 4 continents,$n=2000$ steps and a migration every $100$ steps, the elite contains only $5$ individuals, in order to avoid that every population gets stuck in the same minimum.

# %%
parallel0=open("results/parallel_elitism/best_square_0.dat",'r').read().split('\n')
parallel1=open("results/parallel_elitism/best_square_1.dat",'r').read().split('\n')
parallel2=open("results/parallel_elitism/best_square_2.dat",'r').read().split('\n')
parallel3=open("results/parallel_elitism/best_square_3.dat",'r').read().split('\n')

parallel0=[x.split(',') for x in parallel0]
parallel1=[x.split(',') for x in parallel1]
parallel2=[x.split(',') for x in parallel2]
parallel3=[x.split(',') for x in parallel3]

x=[]
y0=[]
y3=[]
y2=[]
y1=[]

for i in range(len(parallel1)-1):
    x.append(float(parallel0[i][0]))
    y0.append(float(parallel0[i][1]))
    y1.append(float(parallel1[i][1]))
    y2.append(float(parallel2[i][1]))
    y3.append(float(parallel3[i][1]))

plt.figure(figsize=(8,5))

plt.plot(x,y0,label="Core 0")
plt.plot(x,y1,label="Core 1")
plt.plot(x,y2,label="Core 2")
plt.plot(x,y3,label="Core 3")
plt.title("Best individual per generation on different cores")
plt.xlabel("Generation")
plt.ylabel("Tour lenght")

plt.legend()
plt.grid(True)
plt.show()
plt.close()

# %% [markdown]
# And also the average behaviour

# %%
a_parallel0=open("results/parallel_elitism/average_square_0.dat",'r').read().split('\n')
a_parallel1=open("results/parallel_elitism/average_square_1.dat",'r').read().split('\n')
a_parallel2=open("results/parallel_elitism/average_square_2.dat",'r').read().split('\n')
a_parallel3=open("results/parallel_elitism/average_square_3.dat",'r').read().split('\n')

a_parallel0=[x.split(',') for x in a_parallel0]
a_parallel1=[x.split(',') for x in a_parallel1]
a_parallel2=[x.split(',') for x in a_parallel2]
a_parallel3=[x.split(',') for x in a_parallel3]

x=[]
y0=[]
y3=[]
y2=[]
y1=[]

for i in range(len(parallel1)-1):
    x.append(float(a_parallel0[i][0]))
    y0.append(float(a_parallel0[i][1]))
    y1.append(float(a_parallel1[i][1]))
    y2.append(float(a_parallel2[i][1]))
    y3.append(float(a_parallel3[i][1]))

plt.figure(figsize=(8,5))

plt.plot(x,y0,label="Core 0")
plt.plot(x,y1,label="Core 1")
plt.plot(x,y2,label="Core 2")
plt.plot(x,y3,label="Core 3")
plt.title("Average of the best half per generation on different cores")
plt.xlabel("Generation")
plt.ylabel("Tour lenght")

plt.legend()
plt.grid(True)
plt.show()
plt.close()

# %% [markdown]
# As we can see, elitism reaches an optimal result on every core weel before the 2000 steps computed.
#
#
# Here we present a picure of the result found by the parallel genetic algorithm:

# %%
p_best_ind=np.loadtxt("results/parallel_elitism/best_ind_elite.dat")
p_best_ind=[int(x) for x in p_best_ind]

xc=[]
yc=[]



for i in range(len(square)-1):
    a=p_best_ind[i]
    xc.append(float(square[a][0]))
    yc.append(float(square[a][1]))

    
xc.append(xc[0])
yc.append(yc[0])


plt.figure(figsize=(8,8))
plt.title("Best path found with elitism selection GA and parallel cmputing")
plt.plot(xc,yc, marker='o',linestyle='dashed')
plt.xlabel("x")
plt.ylabel("y")

plt.show()
plt.close()

# %% [markdown]
# The figures before show no important evidences of performance improvements using parallel algorithm instead of a single one like in the previous lesson, but it is worth noting that the path found this way is the shortest one, with $d_{total}=93.6728$
