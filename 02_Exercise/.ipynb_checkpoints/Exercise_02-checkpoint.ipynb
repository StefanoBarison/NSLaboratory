# %% [markdown]
# ## Notebook 02
#
# ### EXERCISE 02.1
#
# In this first part we are going to calcuate an integral through Monte Carlo methods.
# The integral to be evaluated is $$I = \int_0^1 \frac{\pi}{2}\cos(\pi x/2) dx = 1$$

# %% [markdown]
# 1. sampling a uniform distribution in $[0,1]$

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
#Create the plot of the first point of Exercise 02.1

data1=open('integral_uniform.txt','r').read().split('\n')

data1=[x.split(',') for x in data1]


x= np.zeros(len(data1)-1)
y= np.zeros(len(data1)-1)
y_err= np.zeros(len(data1)-1)

for i in range(len(data1)-1):
    x[i]=data1[i][0]
    y[i]=data1[i][1]
    y_err[i]=data1[i][2]
    
plt.errorbar(x,y,yerr=y_err)
plt.xlabel('#throws')
plt.ylabel('Integral')
plt.grid(True)
plt.show()

# %% [markdown]
# 2. using importance sampling (i.e. sampling a non-uniform probability in $[0,1]$

# %% [markdown]
# Qui spieghiamo cosa abbiamo fatto

# %%
data2=open('integral_importance.txt','r').read().split('\n')

data2=[x.split(',') for x in data2]


x= np.zeros(len(data2)-1)
y= np.zeros(len(data2)-1)
y_err= np.zeros(len(data2)-1)

for i in range(len(data2)-1):
    x[i]=data2[i][0]
    y[i]=data2[i][1]
    y_err[i]=data2[i][2]
    
plt.errorbar(x,y,yerr=y_err)
plt.xlabel('#throws')
plt.ylabel('Integral')
plt.grid(True)
plt.show()

# %% [markdown]
# ### EXERCISE 02.2
#
# In this exercise we want to generate random walks in 3 dimensions, initially on a lattice of length $a=1$ and then in the free space with step size again $a=1$

# %% [markdown]
# 1. on a cubic lattice with lattice constant $a=1$; at each discrete time the walker makes a forward or backward step of length equal to $a$ in one of the 3 principal directions of the lattice: $x$, $y$ or $z$. We are going to plot $\sqrt{\langle |\vec{r}_N|^2 \rangle}$  as a function of the number of steps $i$ , where $N$ indicates the number of different random walker initialized.
#
# In this case we chose $N=10000$ and the number of steps $i\in [0,100]$.
#
# The value of $\sqrt{\langle |\vec{r}_N|^2 \rangle}$ is calculated by considering for each step the distance squared of each of the $N$ walkers, calculating the mean of those values and then putting it under the square root. The error is calculated as the standard deviation of the mean, which, for the Central Limit Theorem, corresponds to $\sigma_{N}= \frac{\sigma}{\sqrt{N}}$ and $\sigma$ is calculated as the standard deviadion of the sample, namely $$\sigma=\sqrt{\frac{1}{N-1}\sum_{i=1}^{N}(x_{i}-\mu)^{2}}$$
#
# Once $\sigma_{N}$ is calculated, we have to propagate the error, because we are calculating the square root of the mean.

# %%
data3=open('Lattice_walk.txt','r').read().split('\n')

data3=[x.split(',') for x in data3]


x= [i for i in range(len(data3)-1)]
y= np.zeros(len(data3)-1)
y_err= np.zeros(len(data3)-1)

for i in range(len(data3)-1):
    y[i]=data3[i][0]
    y_err[i]=data3[i][1]
    
plt.errorbar(x,y,yerr=y_err)
plt.xlabel('i-th step')
plt.ylabel('Square root of the distance')
plt.grid(True)
plt.show()

# %% [markdown]
# 2. in the continuum; at each discrete time the walker makes a step of length equal to $a=1$ along a **random direction** obtained by sampling **uniformly** the solid angle: $\theta \in [0,\pi]$ and $\phi \in [0,2\pi]$
#
# Here again we chose $N=10000$ and the number of steps $i\in [0,100]$.
#
# The procedure to calculate the mean value and the error is the same as before.

# %%
data4=open('Uniform_walk.txt','r').read().split('\n')

data4=[x.split(',') for x in data4]


x= [i for i in range(len(data4)-1)]
y= np.zeros(len(data4)-1)
y_err= np.zeros(len(data4)-1)

for i in range(len(data4)-1):
    y[i]=data4[i][0]
    y_err[i]=data4[i][1]
    
plt.errorbar(x,y,yerr=y_err)
plt.xlabel('i-th step')
plt.ylabel('Square root of the distance')
plt.grid(True)
plt.show()
